# %%
import pandas as pd
import numpy as np
from itertools import chain
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_2020 = pd.read_csv("C:/suhas/IT2020.csv")

# %%
df_2020
# Out:
#                 Timestamp   Age Gender         City  \
# 0     24/11/2020 11:14:15  26.0   Male       Munich
# 1     24/11/2020 11:14:16  26.0   Male       Berlin
# 2     24/11/2020 11:14:21  29.0   Male       Berlin
# 3     24/11/2020 11:15:24  28.0   Male       Berlin
# 4     24/11/2020 11:15:46  37.0   Male       Berlin
# ...                   ...   ...    ...          ...
# 1248  18/01/2021 15:05:50  31.0   Male       Berlin
# 1249  18/01/2021 17:46:02  33.0   Male       Berlin
# 1250  18/01/2021 23:20:35  39.0   Male       Munich
# 1251  19/01/2021 10:17:58  26.0   Male  Saarbrücken
# 1252  19/01/2021 12:01:11  26.0   Male       Berlin
#
#                                    Position  Total years of experience  \
# 0                          Software Engineer                         5
# 1                          Backend Developer                         7
# 2                          Software Engineer                        12
# ...

# %%
dataTypeSeries = df_2020.dtypes

print(dataTypeSeries)
# Out:
# Timestamp                                                                                                                   object
# Age                                                                                                                        float64
# Gender                                                                                                                      object
# City                                                                                                                        object
# Position                                                                                                                    object
# Total years of experience                                                                                                   object
# Years of experience in Germany                                                                                              object
# ...

# %%
numeric_data = df_2020.select_dtypes(include=[np.number])
categorical_data = df_2020.select_dtypes(exclude=[np.number])

print('numeric dataset and ',numeric_data.shape)
print(' categorical dataset: ',categorical_data.shape )
# Out:
# numeric dataset and  (1253, 4)
#  categorical dataset:  (1253, 19)

# %%
print(df_2020.City.value_counts())
# Out:
# Berlin         681
# Munich         236
# Frankfurt       44
# Hamburg         40
# Stuttgart       26
#               ...
# Minsk            1
# Saarbrücken      1
# Dublin           1
# warsaw           1
# Hildesheim       1
# Name: City, Length: 119, dtype: int64

# %%
plt.boxplot(np.log10(df_2020['Yearly brutto salary (without bonus and stocks) in EUR']))
plt.xlabel('Annual salary without rewards')
plt.title('Yearly brutto salary (without bonus and stocks) in EUR')
plt.ylabel('log10(Salary)')
plt.grid()
plt.show()

# %%
df_2020.groupby('Have you lost your job due to the coronavirus outbreak?').size().plot(kind='bar')
plt.xlabel('Jobs affected due to pandemic') 
plt.ylabel('Count') 
plt.title("People who lost job due to the coronavirus outbreak")
# Out:
# Text(0.5, 1.0, 'People who lost job due to the coronavirus outbreak')

# %%
sns.set_theme(style="darkgrid")
ax = sns.countplot(x="Employ",data=df_2020)

plt.xlabel('Сontract duration') 
plt.ylabel('Count') 
plt.title("Count of people who are having Different contracts")
# Out:
# Text(0.5, 1.0, 'Count of people who are having Different contracts')

# %%
df_2020.Gender.str.get_dummies().sum().plot.pie(label='', autopct='%1.0f%%')
plt.title("Proportion of Genders")
# Out:
# Text(0.5, 1.0, 'Proportion of Genders')

# %%
sns.set()
p8= plt.hist(df_2020['Age'],bins=10)
plt.xlabel('Age') 
plt.ylabel('Count') 
plt.title("Count of different Age")
plt.show(p8)

# %%
ax = sns.boxplot(x="Age", y="Gender", data=df_2020)
plt.xlabel('Age') 
plt.ylabel('Gender') 
plt.title("Box Plot of Gender with diffrent Age Groups")
# Out:
# Text(0.5, 1.0, 'Box Plot of Gender with diffrent Age Groups')

# %%
sns.set_theme(style="darkgrid")
ax = sns.countplot(x="Company size",data=df_2020)
plt.xlabel('Company size') 
plt.ylabel('count') 
plt.title("Number of Employees in a Company")
# Out:
# Text(0.5, 1.0, 'Number of Employees in a Company')
